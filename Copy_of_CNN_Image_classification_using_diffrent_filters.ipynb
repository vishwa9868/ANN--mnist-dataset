# %% [markdown]
# <a href="https://colab.research.google.com/github/vishwa9868/ANN--mnist-dataset/blob/main/Copy_of_CNN_Image_classification_using_diffrent_filters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg # image related ops
import numpy as np
import cv2 # opecv lib

# %%
img_path="/content/data/women/women-1.jpg"

# %%
woman1=mpimg.imread(img_path)

# %%
woman1.shape
# Out:
# (261, 193, 3)

# %%
woman1[239].shape
# Out:
# (193, 3)

# %%
plt.imshow(woman1)

# %%
woman1[0][0]
# Out:
# array([255, 255, 255], dtype=uint8)

# %%
woman1_cv2=cv2.imread(img_path)

# %%
woman1_cv2
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[242, 244, 232],
#         [246, 251, 242],
#         [244, 255, 255],
#         ...,
#         [255, 242, 206],
#         [255, 255, 227],
#         [255, 255, 232]],
#
#        [[255, 255, 245],
#         [247, 245, 234],
#         [218, 223, 221],
#         ...,
#         [139, 115,  69],
#         [204, 182, 141],
#         [255, 255, 226]],
#
#        [[255, 249, 235],
#         [255, 255, 243],
#         [255, 255, 249],
#         ...,
#         [134,  97,  41],
#         [105,  72,  22],
#         [159, 130,  85]]], dtype=uint8)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(woman1_cv2)
# Out:
# <PIL.Image.Image image mode=RGB size=193x261 at 0x7F29686BE1A0>

# %%
plt.imshow(woman1_cv2) # cv2 reads images as BGR and in matplotlib reads as RGB

# %%
woman1_cv2_BGR_RGB = cv2.cvtColor(woman1_cv2,cv2.COLOR_BGR2RGB)
plt.imshow(woman1_cv2_BGR_RGB)

# %%
woman1_cv2_BGR_RGB
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[232, 244, 242],
#         [242, 251, 246],
#         [255, 255, 244],
#         ...,
#         [206, 242, 255],
#         [227, 255, 255],
#         [232, 255, 255]],
#
#        [[245, 255, 255],
#         [234, 245, 247],
#         [221, 223, 218],
#         ...,
#         [ 69, 115, 139],
#         [141, 182, 204],
#         [226, 255, 255]],
#
#        [[235, 249, 255],
#         [243, 255, 255],
#         [249, 255, 255],
#         ...,
#         [ 41,  97, 134],
#         [ 22,  72, 105],
#         [ 85, 130, 159]]], dtype=uint8)

# %%
woman1_cv2_BGR_GRAY = cv2.cvtColor(woman1_cv2,cv2.COLOR_BGR2GRAY)
plt.imshow(woman1_cv2_BGR_GRAY)

# %%
woman1_cv2_BGR_GRAY
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [240, 248, 254, ..., 233, 247, 248],
#        [252, 242, 222, ..., 104, 172, 246],
#        [245, 251, 253, ...,  84,  61, 120]], dtype=uint8)

# %%
woman1_cv2_BGR_GRAY.shape
# Out:
# (261, 193)

# %%
def visualize_RGB_channel(imgArray=None,figsize=(10,7)):
  #spliiting the RGB components
  B , G, R = cv2.split(imgArray)

  #create zero matrix of shape of image
  z = np.zeros(B.shape, dtype=B.dtype) # can use any channel

  #init subplots
  fig, ax = plt.subplots(2,2,figsize=figsize)

  #plotting the actula image RGB images
  [axi.set_axis_off() for axi in ax.ravel()]

  ax[0,0].set_title("original image")
  #ax[0,0].set_axis_off()
  ax[0,0].imshow(cv2.merge((R,G,B)))

  ax[0,1].set_title("Red Ch Image")
  ax[0,1].imshow(cv2.merge((R,z,z)))

  ax[1,0].set_title("Green ch Image")
  ax[1,0].imshow(cv2.merge((z,G,z)))

  ax[1,1].set_title("Blue Ch Image")
  ax[1,1].imshow(cv2.merge((z,z,B)))

# %%
visualize_RGB_channel(imgArray=woman1_cv2)

# %%
random_colored_img=np.random.randint(0 , 255, (6,6,3))

# %%
random_colored_img
# Out:
# array([[[ 42,  98, 175],
#         [178, 229, 178],
#         [250,  48,  68],
#         [224, 202,  66],
#         [247,  56, 113],
#         [ 51, 141,  10]],
#
#        [[192, 146, 136],
#         [ 10, 203, 102],
#         [ 15, 181, 165],
#         [210, 200, 110],
#         [ 45, 175, 115],
#         [236, 147,  84]],
#
#        [[174, 168,  97],
#         [161, 212, 150],
#         [248, 227, 176],
#         [217, 109, 199],
#         [ 21, 210,  40],
#         [245,  90, 167]],
#
#        [[249, 136,  28],
#         [ 30,  87, 253],
#         [155,  50,  14],
#         [212,  90, 128],
#         [244,  49, 192],
#         [ 27, 111,  30]],
#
#        [[194, 187,  14],
#         [ 25,  37,   3],
#         [151, 244,  88],
#         [ 80, 187,  74],
#         [192,  23,  82],
#         [241, 245, 203]],
#
#        [[251, 188, 172],
#         [198,  19,  70],
#         [141,  98, 109],
#         [110, 162, 131],
#         [123,   3, 180],
#         [133, 109, 111]]])

# %%
visualize_RGB_channel(imgArray=random_colored_img)

# %%
#Understanding filters

# %%
sobel=np.array([[1, 0, -1],
                [2, 0, -2],
                [1, 0, -1]])

# %%
print("highlighting vertical edges : \n" , sobel)
# Out:
# highlighting vertical edges :
#  [[ 1  0 -1]
#  [ 2  0 -2]
#  [ 1  0 -1]]

# %%
print("highlighting horizontal edges :\n", sobel.T)
# Out:
# highlighting horizontal edges :
#  [[ 1  2  1]
#  [ 0  0  0]
#  [-1 -2 -1]]

# %%
example1 = [
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,255,255,255,255],
    [0,0,0,0,255,255,255,255,255,255,255,255],
    [0,0,0,0,255,255,255,255,255,255,255,255],
    [0,0,0,0,255,255,255,255,255,255,255,255],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
]

# %%
example1=np.array(example1)

# %%
example1
# Out:
# array([[  0,   0,   0,   0, 255, 255, 255, 255,   0,   0,   0,   0],
#        [  0,   0,   0,   0, 255, 255, 255, 255,   0,   0,   0,   0],
#        [  0,   0,   0,   0, 255, 255, 255, 255,   0,   0,   0,   0],
#        [  0,   0,   0,   0, 255, 255, 255, 255,   0,   0,   0,   0],
#        [  0,   0,   0,   0, 255, 255, 255, 255, 255, 255, 255, 255],
#        [  0,   0,   0,   0, 255, 255, 255, 255, 255, 255, 255, 255],
#        [  0,   0,   0,   0, 255, 255, 255, 255, 255, 255, 255, 255],
#        [  0,   0,   0,   0, 255, 255, 255, 255, 255, 255, 255, 255],
#        [  0,   0,   0,   0, 255, 255, 255, 255,   0,   0,   0,   0],
#        [  0,   0,   0,   0, 255, 255, 255, 255,   0,   0,   0,   0],
#        [  0,   0,   0,   0, 255, 255, 255, 255,   0,   0,   0,   0],
#        [  0,   0,   0,   0, 255, 255, 255, 255,   0,   0,   0,   0]])

# %%
plt.imshow(example1,cmap='gray')

# %%
#def simple_conv(imgFilter=None, picture=None):
  #exteact the shape of the image
  #p_row, p_col = picture.shape

  #k = imgFilter.shape[0] = k = 3

  #temp = list()

  #stride = 1

  # result image size
  #final_cols = (p_col - k)//stride + 1
  #final_rows = (p_row - k)//stride + 1

  #take vertically down stride across row by row
  #for v_stride in range(final_rows):
    # take horizontal right stride across col by col
   # for h_stride in range(final_cols):
    #  target_area_of_pic = picture[v_stride:v_stride + k, h_stride: h_stride + k]
     # z = sum(sum(imgFilter * target_area_of_pic))
      #temp.append(z)

  #resultant_image = np.array(temp).reshape(final_rows,final_cols)
  #return resultant_image

# %%
def simple_conv(imgFilter=None, picture=None):
    # Extract the shape of the image
    p_row, p_col = picture.shape

    k = 3  # Assuming kernel size is fixed as 3x3

    temp = []

    stride = 1

    # Result image size
    final_cols = (p_col - k) // stride + 1
    final_rows = (p_row - k) // stride + 1

    # Take vertical stride down row by row
    for v_stride in range(final_rows):
        # Take horizontal stride across columns
        for h_stride in range(final_cols):
            target_area_of_pic = picture[v_stride:v_stride + k, h_stride: h_stride + k]
            z = np.sum(np.multiply(imgFilter, target_area_of_pic))
            temp.append(z)

    resultant_image = np.array(temp).reshape(final_rows, final_cols)
    return resultant_image

# %%
# Define the Sobel filter
sobel = np.array([
    [-1, 0, 1],
    [-2, 0, 2],
    [-1, 0, 1]])

# %%
# Define the example1 image
example1 = np.array([
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,255,255,255,255],
    [0,0,0,0,255,255,255,255,255,255,255,255],
    [0,0,0,0,255,255,255,255,255,255,255,255],
    [0,0,0,0,255,255,255,255,255,255,255,255],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
])

# %%
# Perform convolution
result = simple_conv(imgFilter=sobel, picture=example1)

# %%
k = 3
v_stride = 0
h_stride = 0 + 1 + 1
target_area = example1[v_stride:v_stride + k, h_stride: h_stride + k]
target_area
# Out:
# array([[  0,   0, 255],
#        [  0,   0, 255],
#        [  0,   0, 255]])

# %%
result
# Out:
# array([[    0,     0,  1020,  1020,     0,     0, -1020, -1020,     0,
#             0],
#        [    0,     0,  1020,  1020,     0,     0, -1020, -1020,     0,
#             0],
#        [    0,     0,  1020,  1020,     0,     0,  -765,  -765,     0,
#             0],
#        [    0,     0,  1020,  1020,     0,     0,  -255,  -255,     0,
#             0],
#        [    0,     0,  1020,  1020,     0,     0,     0,     0,     0,
#             0],
#        [    0,     0,  1020,  1020,     0,     0,     0,     0,     0,
#             0],
#        [    0,     0,  1020,  1020,     0,     0,  -255,  -255,     0,
#             0],
#        [    0,     0,  1020,  1020,     0,     0,  -765,  -765,     0,
#             0],
#        [    0,     0,  1020,  1020,     0,     0, -1020, -1020,     0,
#             0],
#        [    0,     0,  1020,  1020,     0,     0, -1020, -1020,     0,
#             0]])

# %%
import matplotlib.pyplot as plt
plt.imshow(result, cmap='gray')
plt.show()

# %%
result = simple_conv(imgFilter=sobel, picture=example1)

# %%
result = simple_conv(imgFilter=sobel.T, picture=example1)
plt.imshow(result,cmap='gray')

# %%
example2 =[
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0]
    ]

# %%
example2
# Out:
# [[0, 0, 0, 0, 255, 255, 255, 255, 0, 0, 0, 0],
#  [0, 0, 0, 0, 255, 255, 255, 255, 0, 0, 0, 0],
#  [0, 0, 0, 0, 255, 255, 255, 255, 0, 0, 0, 0],
#  [0, 0, 0, 0, 255, 255, 255, 255, 0, 0, 0, 0],
#  [0, 0, 0, 0, 255, 255, 255, 255, 0, 0, 0, 0],
#  [0, 0, 0, 0, 255, 255, 255, 255, 0, 0, 0, 0],
#  [0, 0, 0, 0, 255, 255, 255, 255, 0, 0, 0, 0],
#  [0, 0, 0, 0, 255, 255, 255, 255, 0, 0, 0, 0],
#  [0, 0, 0, 0, 255, 255, 255, 255, 0, 0, 0, 0],
#  [0, 0, 0, 0, 255, 255, 255, 255, 0, 0, 0, 0],
#  [0, 0, 0, 0, 255, 255, 255, 255, 0, 0, 0, 0],
#  [0, 0, 0, 0, 255, 255, 255, 255, 0, 0, 0, 0]]

# %%
plt.imshow(example2,cmap='gray')

# %%
result = simple_conv(imgFilter=sobel.T, picture=example2)
plt.imshow(result,cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-d09265ecaa75> in <cell line: 1>()
# ----> 1 result = simple_conv(imgFilter=sobel.T, picture=example2)
#       2 plt.imshow(result,cmap='gray')
#
# <ipython-input-34-ee9c8c5966e8> in simple_conv(imgFilter, picture)
#       1 def simple_conv(imgFilter=None, picture=None):
#       2     # Extract the shape of the image
# ----> 3     p_row, p_col = picture.shape
#       4
#       5     k = 3  # Assuming kernel size is fixed as 3x3
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
example2_T = np.array(example2.T)
plt.imshow(example2_T, cmap="gray")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-c4ab95bd0c3d> in <cell line: 1>()
# ----> 1 example2_T = np.array(example2.T)
#       2 plt.imshow(example2_T, cmap="gray")
#
# AttributeError: 'list' object has no attribute 'T'

# %%
result = simple_conv(imgFilter=sobel.T,picture=example2.T)
plt.imshow(result,cmap="gray")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-f0bc8ed76eae> in <cell line: 1>()
# ----> 1 result = simple_conv(imgFilter=sobel.T,picture=example2.T)
#       2 plt.imshow(result,cmap="gray")
#
# AttributeError: 'list' object has no attribute 'T'

# %%
result = simple_conv(imgFilter=sobel, picture=woman1_cv2_BGR_GRAY)
plt.imshow(result,cmap='gray')

# %%
result = simple_conv(imgFilter=sobel.T, picture=woman1_cv2_BGR_GRAY)
plt.imshow(result,cmap='gray')

# %%
random_filter=np.random.randn(3,3)
random_filter
# Out:
# array([[-0.46378282,  1.44381447,  1.23051634],
#        [ 0.01996146, -0.4818655 , -0.23391262],
#        [-0.8676363 ,  0.04820198,  0.47576399]])

# %%
result = simple_conv(imgFilter=random_filter, picture=woman1_cv2_BGR_GRAY)
plt.imshow(result,cmap='gray')

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
def read_img(path , grayscale=True):
  img = cv2.imread(path)
  if grayscale:
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    plt.imshow(img,cmap="gray")
    return img
  from google.colab.patches import cv2_imshow
  cv2_imshow(img)
  return img

# %%
woman=read_img(img_path)

# %%
colorfull_women = read_img(img_path , grayscale=False)
# Out:
# <PIL.Image.Image image mode=RGB size=193x261 at 0x7F28C793BB80>

# %%
cnn()

# %%
# (1,r,c,1)
row,col = woman.shape
woman = woman.reshape(1,row,col,1)# grayscale
#colourfuul_women = colourfull_women.reshape(1,row,col,3)# colored
woman.shape
# Out:
# (1, 261, 193, 1)

# %%
CONV_LAYER = [tf.keras.layers.Conv2D(filters=1,
                                     kernel_size=(3,3),
                                     strides=(1,1),
                                     input_shape=woman.shape[1:])]
conv_model = tf.keras.Sequential(CONV_LAYER)
conv_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 259, 191, 1)       10
#
# =================================================================
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________

# %%
out=conv_model.predict(woman)
# Out:
# 1/1 [==============================] - 0s 191ms/step

# %%
out.shape
# Out:
# (1, 259, 191, 1)

# %%
row,col=out.shape[1:-1]

# %%
reshape_out=out.reshape(row, col)

# %%
plt.imshow(reshape_out, cmap="gray")

# %%
#(1,r,c,1)
row,col,depth = colorfull_women.shape
#woman = woman.reshape(1,row,col,1)# grayscale
colorfull_women = colorfull_women.reshape(1,row,col,3)# colored
colorfull_women.shape
# Out:
# (1, 261, 193, 3)

# %%
def reshaping_in(img,grayscale=True):
  if grayscale:
    row,col = img.input_shape
    img = img.reshape(1,row,col,1)#grayscale
    return img
  row,col,depth = img.shape
  color_img = img.reshape(1,row,col,depth)#colored
  return color_img

def get_conv_model(filters=1,filter_size=(3,3),strides=(1,1),input_shape=None,padding="valid"):
  CONV_LAYER = [tf.keras.layers.Conv2D(filters=filters,
                                       kernel_size=filter_size,
                                       strides=(1,1),
                                       input_shape=input_shape,
                                       padding=padding)]

  conv_model = tf.keras.Sequential(CONV_LAYER)
  conv_model.summary()
  return conv_model

def apply_conv_model_and_visualize(img, conv_model):
  try:
    out = conv_model.predict(img)
    print(out.shape)
    row, col, depth = out.shape[1:]
    reshape_out = out.reshape(row, col, depth)

    for d in range(depth):
      plt.imshow(reshape_out[:,:,d], cmap="gray")
      plt.show()

  except Exception as e:
      raise np.e

# %%
img = read_img(img_path,grayscale=False)
input_img = reshaping_in(img, grayscale=False)
model = get_conv_model(filters=1, filter_size=(3,3),strides=(1,1), input_shape=input_img.shape[1:])
apply_conv_model_and_visualize(input_img, model)
# Out:
# <PIL.Image.Image image mode=RGB size=193x261 at 0x7F28C4C3ED10>
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 259, 191, 1)       28
#
# =================================================================
# Total params: 28
# Trainable params: 28
# Non-trainable params: 0
# _________________________________________________________________
# 1/1 [==============================] - 0s 43ms/step
# (1, 259, 191, 1)

# %%
img = read_img(img_path,grayscale=False)
input_img = reshaping_in(img, grayscale=False)
model = get_conv_model(filters=10, filter_size=(3,3),strides=(1,1), input_shape=input_img.shape[1:])
apply_conv_model_and_visualize(input_img, model)
# Out:
# <PIL.Image.Image image mode=RGB size=193x261 at 0x7F28BDFAC5E0>
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 259, 191, 10)      280
#
# =================================================================
# Total params: 280
# Trainable params: 280
# Non-trainable params: 0
# _________________________________________________________________
# 1/1 [==============================] - 0s 50ms/step
# (1, 259, 191, 10)

# %%
img = read_img(img_path,grayscale=False)
input_img = reshaping_in(img, grayscale=False)
model = get_conv_model(filters=10, filter_size=(3,3),strides=(1,1), input_shape=input_img.shape[1:],padding = "same")
apply_conv_model_and_visualize(input_img, model)
# Out:
# <PIL.Image.Image image mode=RGB size=193x261 at 0x7F28C42B3010>
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 261, 193, 10)      280
#
# =================================================================
# Total params: 280
# Trainable params: 280
# Non-trainable params: 0
# _________________________________________________________________
# 1/1 [==============================] - 0s 37ms/step
# (1, 261, 193, 10)

# %%
def max_pooling(img, pool_size=(2,2),strides=(2,2)):
  reshaped_img = reshaping_in(img)
  pooling_layer = tf.keras.layers.MaxPool2D(pool_size=pool_size, strides=strides)
  result = pooling_layer(reshaped_img)
  return result

# %%
img = read_img(img_path)
print(img.shape)
result = max_pooling(img)
print(result.shape)
# Out:
# (261, 193)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-f068585208ba> in <cell line: 3>()
#       1 img = read_img(img_path)
#       2 print(img.shape)
# ----> 3 result = max_pooling(img)
#       4 print(result.shape)
#
# <ipython-input-79-3e92921944e5> in max_pooling(img, pool_size, strides)
#       1 def max_pooling(img, pool_size=(2,2),strides=(2,2)):
# ----> 2   reshaped_img = reshaping_in(img)
#       3   pooling_layer = tf.keras.layers.MaxPool2D(pool_size=pool_size, strides=strides)
#       4   result = pooling_layer(reshaped_img)
#       5   return result
#
# <ipython-input-66-cebeaa6d7914> in reshaping_in(img, grayscale)
#       1 def reshaping_in(img,grayscale=True):
#       2   if grayscale:
# ----> 3     row,col = img.input_shape
#       4     img = img.reshape(1,row,col,1)#grayscale
#       5     return img
#
# AttributeError: 'numpy.ndarray' object has no attribute 'input_shape'

# %%
def plot_pooling(result):
  _, row, col, _ =result.shapereshape = tf.reshape(result, (row,col))
  plt.imshow(reshape, cmap='gray')

# %%
plot_pooling(result)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-82-9083da8a7744> in <cell line: 1>()
# ----> 1 plot_pooling(result)
#
# <ipython-input-81-d88f354b4e61> in plot_pooling(result)
#       1 def plot_pooling(result):
# ----> 2   _, row, col, _ =result.shapereshape = tf.reshape(result, (row,col))
#       3   plt.imshow(reshape, cmap='gray')
#
# UnboundLocalError: local variable 'row' referenced before assignment
